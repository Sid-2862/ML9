# %% [markdown]
# <a href="https://colab.research.google.com/github/Sid-2862/ML9/blob/main/Association_Rule_Mining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install apyori
# Out:
# Requirement already satisfied: apyori in /usr/local/lib/python3.11/dist-packages (1.1.2)

# %% [markdown]
# ##  Association Rule mining

# %%
import pandas as pd
path = r"https://raw.githubusercontent.com/Sindhura-tr/Datasets/refs/heads/main/store_data.csv"
df = pd.read_csv(path,header=None)
df.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# 0  low fat yogurt  green tea  honey  salad  mineral water  salmon
# 1             NaN        NaN    NaN    NaN            NaN     NaN
# 2             NaN        NaN    NaN    NaN            NaN     NaN
# 3             NaN        NaN    NaN    NaN            NaN     NaN
# 4             NaN        NaN    NaN    NaN            NaN     NaN
#
#                   16               17       18         19
# 0  antioxydant juice  frozen smoothie  spinach  olive oil
# 1                NaN              NaN      NaN        NaN
# 2                NaN              NaN      NaN        NaN
# 3                NaN              NaN      NaN        NaN
# 4                NaN              NaN      NaN        NaN

# %%
df.shape
# Out:
# (7501, 20)

# %% [markdown]
# [[shrimp,almonds,avocado,......], [burgers,meatballs,eggs], [chutney], .. .. ]

# %%
df.shape[0]
# Out:
# 7501

# %%
df.shape[1]
# Out:
# 20

# %%
df.values[0,0]
# Out:
# 'shrimp'

# %%
records = []
for i in range(df.shape[0]):
  records.append([str(df.values[i,j]) for j in range(df.shape[1])])
records[:50]
# Out:
# [['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea',
#   'honey',
#   'salad',
#   'mineral water',
#   'salmon',
#   'antioxydant juice',
#   'frozen smoothie',
#   'spinach',
#   'olive oil'],
#  ['burgers',
#   'meatballs',
#   'eggs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chutney',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'avocado',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['mineral water',
#   'milk',
#   'energy bar',
#   'whole wheat rice',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['low fat yogurt',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole wheat pasta',
#   'french fries',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['soup',
#   'light cream',
#   'shallot',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['frozen vegetables',
#   'spaghetti',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['french fries',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['eggs',
#   'pet food',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['cookies',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'burgers',
#   'mineral water',
#   'eggs',
#   'cooking oil',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['spaghetti',
#   'champagne',
#   'cookies',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['mineral water',
#   'salmon',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['mineral water',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['shrimp',
#   'chocolate',
#   'chicken',
#   'honey',
#   'oil',
#   'cooking oil',
#   'low fat yogurt',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'eggs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'fresh tuna',
#   'tomatoes',
#   'spaghetti',
#   'mineral water',
#   'black tea',
#   'salmon',
#   'eggs',
#   'chicken',
#   'extra dark chocolate',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['meatballs',
#   'milk',
#   'honey',
#   'french fries',
#   'protein bar',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['red wine',
#   'shrimp',
#   'pasta',
#   'pepper',
#   'eggs',
#   'chocolate',
#   'shampoo',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['rice',
#   'sparkling water',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['spaghetti',
#   'mineral water',
#   'ham',
#   'body spray',
#   'pancakes',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['burgers',
#   'grated cheese',
#   'shrimp',
#   'pasta',
#   'avocado',
#   'honey',
#   'white wine',
#   'toothpaste',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['eggs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['parmesan cheese',
#   'spaghetti',
#   'soup',
#   'avocado',
#   'milk',
#   'fresh bread',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['ground beef',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'energy bar',
#   'black tea',
#   'salmon',
#   'frozen smoothie',
#   'escalope',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['sparkling water',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['mineral water',
#   'eggs',
#   'chicken',
#   'chocolate',
#   'french fries',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['frozen vegetables',
#   'spaghetti',
#   'yams',
#   'mineral water',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['herb & pepper',
#   'tomato sauce',
#   'light cream',
#   'magazines',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['mineral water',
#   'chocolate',
#   'avocado',
#   'eggs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'french fries',
#   'strawberries',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['frozen vegetables',
#   'strong cheese',
#   'chocolate',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['cookies',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['pickles',
#   'spaghetti',
#   'salmon',
#   'escalope',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['energy bar',
#   'french fries',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['red wine',
#   'ground beef',
#   'mineral water',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['mineral water',
#   'cake',
#   'cottage cheese',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['pickles',
#   'champagne',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['spaghetti',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['fresh tuna',
#   'frozen vegetables',
#   'spaghetti',
#   'mineral water',
#   'honey',
#   'whole wheat rice',
#   'frozen smoothie',
#   'escalope',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['spaghetti',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['soup',
#   'meatballs',
#   'hot dogs',
#   'sparkling water',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['escalope',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['soup',
#   'avocado',
#   'french fries',
#   'hot dogs',
#   'brownies',
#   'body spray',
#   'pancakes',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['mineral water',
#   'chicken',
#   'cereals',
#   'clothes accessories',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['mineral water',
#   'bug spray',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['avocado',
#   'muffins',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['burgers',
#   'black tea',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan']]

# %% [markdown]
# ## Criteria: Set the minimum values for Confidence, Support, Lift
# Confidence = 0.2 support = 7*5/len(df) lift = 3

# %%
    conf = 0.2
    sup = 35/len(df)
    lift = 3

# %%
from apyori import apriori
association_rules =  apriori(records,min_support=0.0045,min_confidence=0.2,min_lift=lift)
association_rules = list(association_rules)
association_rules[0]
# Out:
# RelationRecord(items=frozenset({'light cream', 'chicken'}), support=0.004532728969470737, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light cream'}), items_add=frozenset({'chicken'}), confidence=0.29059829059829057, lift=4.84395061728395)])

# %%
# association rule
association_rules[0][0]
# Out:
# frozenset({'chicken', 'light cream'})

# %%
# support details
association_rules[0][1]
# Out:
# 0.004532728969470737

# %%
# confidence details
association_rules[0][2][0][2]
# Out:
# 0.29059829059829057

# %%
# lift details
association_rules[0][2][0][3]
# Out:
# 4.84395061728395

# %%
len(association_rules)
# Out:
# 48

# %%
pair0 = association_rules[0][0]
items0 = []
for i in pair0:
  #print(i)
  items0.append(i)
items0
print("Associaiton rules: " + items0[0] + "----->" + items0[1])
# Out:
# Associaiton rules: light cream----->chicken

# %%
for item in association_rules:
  pair = item[0]

  items =[i for i in pair]
  print("Association Rule: " + items[0]  + "-------->" + items[1])

  sup = item[1]
  print("Support: "+str(item[1]))

  conf = str(item[2][0][2])
  lift = str(item[2][0][3])
  print("Confidence : "+ conf)
  print("Lift : "+lift)
  print("--------------------------------")
# Out:
# Association Rule: light cream-------->chicken
# Support: 0.004532728969470737
# Confidence : 0.29059829059829057
# Lift : 4.84395061728395
# --------------------------------
# Association Rule: mushroom cream sauce-------->escalope
# Support: 0.005732568990801226
# Confidence : 0.3006993006993007
# Lift : 3.790832696715049
# --------------------------------
# Association Rule: escalope-------->pasta
# Support: 0.005865884548726837
# Confidence : 0.3728813559322034
# Lift : 4.700811850163794
# --------------------------------
# Association Rule: ground beef-------->herb & pepper
# Support: 0.015997866951073192
# Confidence : 0.3234501347708895
# Lift : 3.2919938411349285
# --------------------------------
# Association Rule: ground beef-------->tomato sauce
# Support: 0.005332622317024397
# Confidence : 0.3773584905660377
# Lift : 3.840659481324083
# --------------------------------
# Association Rule: whole wheat pasta-------->olive oil
# Support: 0.007998933475536596
# Confidence : 0.2714932126696833
# Lift : 4.122410097642296
# --------------------------------
# Association Rule: shrimp-------->pasta
# Support: 0.005065991201173177
# Confidence : 0.3220338983050847
# Lift : 4.506672147735896
# --------------------------------
# Association Rule: nan-------->light cream
# Support: 0.004532728969470737
# Confidence : 0.29059829059829057
# Lift : 4.84395061728395
# --------------------------------
# Association Rule: shrimp-------->frozen vegetables
# Support: 0.005332622317024397
# Confidence : 0.23255813953488375
# Lift : 3.2545123221103784
# --------------------------------
# Association Rule: ground beef-------->cooking oil
# Support: 0.004799360085321957
# Confidence : 0.5714285714285714
# Lift : 3.2819951870487856
# --------------------------------
# Association Rule: mushroom cream sauce-------->nan
# Support: 0.005732568990801226
# Confidence : 0.3006993006993007
# Lift : 3.790832696715049
# --------------------------------
# Association Rule: nan-------->escalope
# Support: 0.005865884548726837
# Confidence : 0.3728813559322034
# Lift : 4.700811850163794
# --------------------------------
# Association Rule: ground beef-------->frozen vegetables
# Support: 0.008665511265164644
# Confidence : 0.31100478468899523
# Lift : 3.165328208890303
# --------------------------------
# Association Rule: milk-------->frozen vegetables
# Support: 0.004799360085321957
# Confidence : 0.20338983050847456
# Lift : 3.088314005352364
# --------------------------------
# Association Rule: shrimp-------->frozen vegetables
# Support: 0.007199040127982935
# Confidence : 0.30508474576271183
# Lift : 3.200616332819722
# --------------------------------
# Association Rule: spaghetti-------->frozen vegetables
# Support: 0.005732568990801226
# Confidence : 0.20574162679425836
# Lift : 3.1240241752707125
# --------------------------------
# Association Rule: shrimp-------->frozen vegetables
# Support: 0.005999200106652446
# Confidence : 0.21531100478468898
# Lift : 3.0131489680782684
# --------------------------------
# Association Rule: tomatoes-------->frozen vegetables
# Support: 0.006665777896280496
# Confidence : 0.23923444976076558
# Lift : 3.4980460188216425
# --------------------------------
# Association Rule: grated cheese-------->ground beef
# Support: 0.005332622317024397
# Confidence : 0.3225806451612903
# Lift : 3.283144395325426
# --------------------------------
# Association Rule: ground beef-------->mineral water
# Support: 0.006665777896280496
# Confidence : 0.39062500000000006
# Lift : 3.975682666214383
# --------------------------------
# Association Rule: nan-------->ground beef
# Support: 0.015997866951073192
# Confidence : 0.3234501347708895
# Lift : 3.2919938411349285
# --------------------------------
# Association Rule: ground beef-------->herb & pepper
# Support: 0.006399146780429276
# Confidence : 0.3934426229508197
# Lift : 4.004359721511667
# --------------------------------
# Association Rule: milk-------->ground beef
# Support: 0.004932675643247567
# Confidence : 0.22424242424242427
# Lift : 3.40494417862839
# --------------------------------
# Association Rule: nan-------->ground beef
# Support: 0.005332622317024397
# Confidence : 0.3773584905660377
# Lift : 3.840659481324083
# --------------------------------
# Association Rule: ground beef-------->shrimp
# Support: 0.005999200106652446
# Confidence : 0.5232558139534884
# Lift : 3.005315360233627
# --------------------------------
# Association Rule: milk-------->spaghetti
# Support: 0.007199040127982935
# Confidence : 0.20300751879699247
# Lift : 3.0825089038385434
# --------------------------------
# Association Rule: soup-------->mineral water
# Support: 0.005199306759098787
# Confidence : 0.22543352601156072
# Lift : 3.4230301186492245
# --------------------------------
# Association Rule: nan-------->whole wheat pasta
# Support: 0.007998933475536596
# Confidence : 0.2714932126696833
# Lift : 4.13077198425009
# --------------------------------
# Association Rule: nan-------->shrimp
# Support: 0.005065991201173177
# Confidence : 0.3220338983050847
# Lift : 4.515095833993347
# --------------------------------
# Association Rule: pancakes-------->spaghetti
# Support: 0.005065991201173177
# Confidence : 0.20105820105820105
# Lift : 3.0529100529100526
# --------------------------------
# Association Rule: nan-------->shrimp
# Support: 0.005332622317024397
# Confidence : 0.23255813953488375
# Lift : 3.260595522712454
# --------------------------------
# Association Rule: nan-------->ground beef
# Support: 0.004799360085321957
# Confidence : 0.5714285714285714
# Lift : 3.2819951870487856
# --------------------------------
# Association Rule: nan-------->ground beef
# Support: 0.008665511265164644
# Confidence : 0.31100478468899523
# Lift : 3.165328208890303
# --------------------------------
# Association Rule: spaghetti-------->milk
# Support: 0.004532728969470737
# Confidence : 0.28813559322033894
# Lift : 3.0228043143297376
# --------------------------------
# Association Rule: milk-------->olive oil
# Support: 0.004799360085321957
# Confidence : 0.20338983050847456
# Lift : 3.094578333963626
# --------------------------------
# Association Rule: nan-------->shrimp
# Support: 0.007199040127982935
# Confidence : 0.30508474576271183
# Lift : 3.200616332819722
# --------------------------------
# Association Rule: spaghetti-------->nan
# Support: 0.005732568990801226
# Confidence : 0.20574162679425836
# Lift : 3.1303609383037156
# --------------------------------
# Association Rule: nan-------->shrimp
# Support: 0.005999200106652446
# Confidence : 0.21531100478468898
# Lift : 3.0187810222242093
# --------------------------------
# Association Rule: nan-------->tomatoes
# Support: 0.006665777896280496
# Confidence : 0.23923444976076558
# Lift : 3.4980460188216425
# --------------------------------
# Association Rule: nan-------->grated cheese
# Support: 0.005332622317024397
# Confidence : 0.3225806451612903
# Lift : 3.283144395325426
# --------------------------------
# Association Rule: nan-------->ground beef
# Support: 0.006665777896280496
# Confidence : 0.39062500000000006
# Lift : 3.975682666214383
# --------------------------------
# Association Rule: nan-------->ground beef
# Support: 0.006399146780429276
# Confidence : 0.3934426229508197
# Lift : 4.004359721511667
# --------------------------------
# Association Rule: milk-------->ground beef
# Support: 0.004932675643247567
# Confidence : 0.22424242424242427
# Lift : 3.4118507591124225
# --------------------------------
# Association Rule: nan-------->ground beef
# Support: 0.005999200106652446
# Confidence : 0.5232558139534884
# Lift : 3.005315360233627
# --------------------------------
# Association Rule: milk-------->olive oil
# Support: 0.007199040127982935
# Confidence : 0.20300751879699247
# Lift : 3.088761457396025
# --------------------------------
# Association Rule: soup-------->nan
# Support: 0.005199306759098787
# Confidence : 0.22543352601156072
# Lift : 3.429973384609973
# --------------------------------
# Association Rule: pancakes-------->nan
# Support: 0.005065991201173177
# Confidence : 0.20105820105820105
# Lift : 3.0591025682303568
# --------------------------------
# Association Rule: frozen vegetables-------->milk
# Support: 0.004532728969470737
# Confidence : 0.28813559322033894
# Lift : 3.0228043143297376
# --------------------------------

# %%
rules = []
supports = []
confs = []
lifts =[]

for item in association_rules:
  pair = item[0]

  items =[i for i in pair]
  ru = (items[0]  + "-->" + items[1])
  rules.append(ru)


  sup = item[1]

  supports.append(sup)

  conf = (item[2][0][2])
  lift = (item[2][0][3])

  confs.append(conf)
  lifts.append(lift)

# %%
rules
# Out:
# ['light cream-->chicken',
#  'mushroom cream sauce-->escalope',
#  'escalope-->pasta',
#  'ground beef-->herb & pepper',
#  'ground beef-->tomato sauce',
#  'whole wheat pasta-->olive oil',
#  'shrimp-->pasta',
#  'nan-->light cream',
#  'shrimp-->frozen vegetables',
#  'ground beef-->cooking oil',
#  'mushroom cream sauce-->nan',
#  'nan-->escalope',
#  'ground beef-->frozen vegetables',
#  'milk-->frozen vegetables',
#  'shrimp-->frozen vegetables',
#  'spaghetti-->frozen vegetables',
#  'shrimp-->frozen vegetables',
#  'tomatoes-->frozen vegetables',
#  'grated cheese-->ground beef',
#  'ground beef-->mineral water',
#  'nan-->ground beef',
#  'ground beef-->herb & pepper',
#  'milk-->ground beef',
#  'nan-->ground beef',
#  'ground beef-->shrimp',
#  'milk-->spaghetti',
#  'soup-->mineral water',
#  'nan-->whole wheat pasta',
#  'nan-->shrimp',
#  'pancakes-->spaghetti',
#  'nan-->shrimp',
#  'nan-->ground beef',
#  'nan-->ground beef',
#  'spaghetti-->milk',
#  'milk-->olive oil',
#  'nan-->shrimp',
#  'spaghetti-->nan',
#  'nan-->shrimp',
#  'nan-->tomatoes',
#  'nan-->grated cheese',
#  'nan-->ground beef',
#  'nan-->ground beef',
#  'milk-->ground beef',
#  'nan-->ground beef',
#  'milk-->olive oil',
#  'soup-->nan',
#  'pancakes-->nan',
#  'frozen vegetables-->milk']

# %%
supports
# Out:
# [0.004532728969470737,
#  0.005732568990801226,
#  0.005865884548726837,
#  0.015997866951073192,
#  0.005332622317024397,
#  0.007998933475536596,
#  0.005065991201173177,
#  0.004532728969470737,
#  0.005332622317024397,
#  0.004799360085321957,
#  0.005732568990801226,
#  0.005865884548726837,
#  0.008665511265164644,
#  0.004799360085321957,
#  0.007199040127982935,
#  0.005732568990801226,
#  0.005999200106652446,
#  0.006665777896280496,
#  0.005332622317024397,
#  0.006665777896280496,
#  0.015997866951073192,
#  0.006399146780429276,
#  0.004932675643247567,
#  0.005332622317024397,
#  0.005999200106652446,
#  0.007199040127982935,
#  0.005199306759098787,
#  0.007998933475536596,
#  0.005065991201173177,
#  0.005065991201173177,
#  0.005332622317024397,
#  0.004799360085321957,
#  0.008665511265164644,
#  0.004532728969470737,
#  0.004799360085321957,
#  0.007199040127982935,
#  0.005732568990801226,
#  0.005999200106652446,
#  0.006665777896280496,
#  0.005332622317024397,
#  0.006665777896280496,
#  0.006399146780429276,
#  0.004932675643247567,
#  0.005999200106652446,
#  0.007199040127982935,
#  0.005199306759098787,
#  0.005065991201173177,
#  0.004532728969470737]

# %% [markdown]
# ## Create a dictionary to save the associations formed

# %%
dct = {
    "Rules":rules,
    "Support":supports,
    "Confidence":confs,
    "Lift":lifts
}

# %%
from typing_extensions import final
final_associations = pd.DataFrame(dct)
final_associations
# Out:
#                               Rules   Support  Confidence      Lift
# 0             light cream-->chicken  0.004533    0.290598  4.843951
# 1   mushroom cream sauce-->escalope  0.005733    0.300699  3.790833
# 2                  escalope-->pasta  0.005866    0.372881  4.700812
# 3       ground beef-->herb & pepper  0.015998    0.323450  3.291994
# 4        ground beef-->tomato sauce  0.005333    0.377358  3.840659
# 5     whole wheat pasta-->olive oil  0.007999    0.271493  4.122410
# 6                    shrimp-->pasta  0.005066    0.322034  4.506672
# 7                 nan-->light cream  0.004533    0.290598  4.843951
# 8        shrimp-->frozen vegetables  0.005333    0.232558  3.254512
# 9         ground beef-->cooking oil  0.004799    0.571429  3.281995
# 10       mushroom cream sauce-->nan  0.005733    0.300699  3.790833
# 11                   nan-->escalope  0.005866    0.372881  4.700812
# 12  ground beef-->frozen vegetables  0.008666    0.311005  3.165328
# 13         milk-->frozen vegetables  0.004799    0.203390  3.088314
# 14       shrimp-->frozen vegetables  0.007199    0.305085  3.200616
# 15    spaghetti-->frozen vegetables  0.005733    0.205742  3.124024
# 16       shrimp-->frozen vegetables  0.005999    0.215311  3.013149
# 17     tomatoes-->frozen vegetables  0.006666    0.239234  3.498046
# 18      grated cheese-->ground beef  0.005333    0.322581  3.283144
# 19      ground beef-->mineral water  0.006666    0.390625  3.975683
# 20                nan-->ground beef  0.015998    0.323450  3.291994
# 21      ground beef-->herb & pepper  0.006399    0.393443  4.004360
# 22               milk-->ground beef  0.004933    0.224242  3.404944
# 23                nan-->ground beef  0.005333    0.377358  3.840659
# 24             ground beef-->shrimp  0.005999    0.523256  3.005315
# 25                 milk-->spaghetti  0.007199    0.203008  3.082509
# 26             soup-->mineral water  0.005199    0.225434  3.423030
# 27          nan-->whole wheat pasta  0.007999    0.271493  4.130772
# 28                     nan-->shrimp  0.005066    0.322034  4.515096
# 29             pancakes-->spaghetti  0.005066    0.201058  3.052910
# 30                     nan-->shrimp  0.005333    0.232558  3.260596
# 31                nan-->ground beef  0.004799    0.571429  3.281995
# 32                nan-->ground beef  0.008666    0.311005  3.165328
# 33                 spaghetti-->milk  0.004533    0.288136  3.022804
# 34                 milk-->olive oil  0.004799    0.203390  3.094578
# 35                     nan-->shrimp  0.007199    0.305085  3.200616
# 36                  spaghetti-->nan  0.005733    0.205742  3.130361
# 37                     nan-->shrimp  0.005999    0.215311  3.018781
# 38                   nan-->tomatoes  0.006666    0.239234  3.498046
# 39              nan-->grated cheese  0.005333    0.322581  3.283144
# 40                nan-->ground beef  0.006666    0.390625  3.975683
# 41                nan-->ground beef  0.006399    0.393443  4.004360
# 42               milk-->ground beef  0.004933    0.224242  3.411851
# 43                nan-->ground beef  0.005999    0.523256  3.005315
# 44                 milk-->olive oil  0.007199    0.203008  3.088761
# 45                       soup-->nan  0.005199    0.225434  3.429973
# 46                   pancakes-->nan  0.005066    0.201058  3.059103
# 47         frozen vegetables-->milk  0.004533    0.288136  3.022804

# %% [markdown]
# ## Save the results to output file

# %%
final_associations.to_csv("Associations_Ready.csv",index=False)
